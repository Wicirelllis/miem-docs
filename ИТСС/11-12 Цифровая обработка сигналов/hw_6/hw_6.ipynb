# %% [markdown]
# ## Предисловие
#
# Группы ячеек для каждого задания раскрываются.
#
# Графики - диаграммы Боде [wiki](https://en.wikipedia.org/wiki/Bode_plot) (ЛАФЧХ, Логарифмическая амплитудно-фазовая частотная характеристика(!)).
# Это парные графики, верхний - АЧХ, нижний - ФЧХ.
# Горизонтальная ось - частота, причем в лог-масштабе.
# Вертикальная - усилене в дБ для АЧХ, сдвиг фазы в градусах для ФЧХ.
#
# Параметры типо как в ```signal.cheby1(4, 5, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))``` брал просто из примеров документации сайпая.

# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from scipy import fft, signal

# %%
def make_plot(title: str, w: list, mag: list, phase: list) -> None:
    subtitle = ["lowpass", "highpass", "bandpass", "bandstop"]
    fig = plt.figure(figsize=(10, 8), dpi=130)
    outer = gridspec.GridSpec(2, 2)

    for i in range(4):
        inner = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=outer[i])

        ax = plt.Subplot(fig, inner[0])
        ax.set_title(subtitle[i])
        ax.semilogx(w[i], mag[i])
        ax.grid(which='both', axis='both')
        fig.add_subplot(ax)

        ax = plt.Subplot(fig, inner[1])
        ax.semilogx(w[i], phase[i])
        ax.grid(which='both', axis='both')
        fig.add_subplot(ax)

    fig.suptitle(title)
    fig.tight_layout()

# %% [markdown]
# ## Задание 1
# Цифровые фильтры

# %%
data = []
data.append(signal.dbode(signal.TransferFunction(*signal.butter(4, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.butter(4, 200, btype="highpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.butter(4, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.butter(4, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000), dt=0.05)))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Butterworth, digital", w, mag, phase)

# %%
data = []
data.append(signal.dbode(signal.TransferFunction(*signal.cheby1(4, 5, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby1(4, 5, 200, btype="highpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby1(4, 5, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby1(4, 5, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000), dt=0.05)))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Chebyshev type I, digital", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = []
data.append(signal.dbode(signal.TransferFunction(*signal.cheby2(4, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby2(4, 40, 200, btype="highpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby2(4, 40, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.cheby2(4, 40, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000), dt=0.05)))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Chebyshev type II, digital", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = []
data.append(signal.dbode(signal.TransferFunction(*signal.ellip(4, 5, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.ellip(4, 5, 40, 200, btype="highpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.ellip(4, 5, 40, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000), dt=0.05)))
data.append(signal.dbode(signal.TransferFunction(*signal.ellip(4, 5, 40, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000), dt=0.05)))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Elliptic, digital", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Задание 2
# Аналоговые фильтры

# %%
data = []
data.append(signal.bode(signal.butter(3, 100, btype="lowpass", analog=True, output="ba")))
data.append(signal.bode(signal.butter(3, 200, btype="highpass", analog=True, output="ba")))
data.append(signal.bode(signal.butter(3, [100, 1000], btype="bandpass", analog=True, output="ba")))
data.append(signal.bode(signal.butter(3, [100, 1000], btype="bandstop", analog=True, output="ba")))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Butterworth, analog", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = []
data.append(signal.bode(signal.cheby1(4, 5, 100, btype="lowpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby1(4, 5, 200, btype="highpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby1(4, 5, [100, 1000], btype="bandpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby1(4, 5, [100, 1000], btype="bandstop", analog=True, output="ba")))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Chebyshev type I, analog", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = []
data.append(signal.bode(signal.cheby2(4, 5, 100, btype="lowpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby2(4, 5, 200, btype="highpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby2(4, 5, [100, 1000], btype="bandpass", analog=True, output="ba")))
data.append(signal.bode(signal.cheby2(4, 5, [100, 1000], btype="bandstop", analog=True, output="ba")))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Chebyshev type II, analog", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data = []
data.append(signal.bode(signal.ellip(4, 5, 40, 100, btype="lowpass", analog=True, output="ba")))
data.append(signal.bode(signal.ellip(4, 5, 40, 200, btype="highpass", analog=True, output="ba")))
data.append(signal.bode(signal.ellip(4, 5, 40, [100, 1000], btype="bandpass", analog=True, output="ba")))
data.append(signal.bode(signal.ellip(4, 5, 40, [100, 1000], btype="bandstop", analog=True, output="ba")))

w = [i[0] for i in data]
mag = [i[1] for i in data]
phase = [i[2] for i in data]
make_plot("Elliptic, analog", w, mag, phase)
# Out:
# C:\Users\Wicirelllis\AppData\Local\Temp\ipykernel_1760\1331548707.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Задание 3
# Построить нули и полюса цифровых фильтров.
#
# Кружочки - нули, крестики - полюса.
# Также я добавил серую единичную окружность для более понятного масштаба.

# %%
def zero_pole_plot(title: str, z: list, p: list) -> None:
    subtitle = ["lowpass", "highpass", "bandpass", "bandstop"]
    fig = plt.figure(figsize=(10, 8), dpi=130)
    outer = gridspec.GridSpec(2, 2)

    for i in range(4):
        ax = plt.Subplot(fig, outer[i])
        ax.axis('equal')
        ax.set_title(subtitle[i])
        cir = plt.Circle((0, 0), 1, color="grey", fill=False)
        ax.add_patch(cir)
        ax.plot(z[i].real, z[i].imag, "o")
        ax.plot(p[i].real, p[i].imag, "x")
        ax.grid(which='both', axis='both')
        fig.add_subplot(ax)

    fig.suptitle(title)
    fig.tight_layout()

# %%
data = []
data.append(signal.butter(4, 100, btype="lowpass", analog=False, output="zpk", fs=10_000))
data.append(signal.butter(4, 200, btype="highpass", analog=False, output="zpk", fs=10_000))
data.append(signal.butter(4, [100, 1000], btype="bandpass", analog=False, output="zpk", fs=10_000))
data.append(signal.butter(4, [100, 1000], btype="bandstop", analog=False, output="zpk", fs=10_000))

z = [i[0] for i in data]
p = [i[1] for i in data]
q = signal.butter(4, 100, btype="lowpass", analog=False, output="zpk", fs=10_000)
zero_pole_plot("Butterworth, digital", z, p)

# %%
data = []
data.append(signal.cheby1(4, 5, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby1(4, 5, 200, btype="highpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby1(4, 5, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby1(4, 5, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000))



z = [i[0] for i in data]
p = [i[1] for i in data]
q = signal.butter(4, 100, btype="lowpass", analog=False, output="zpk", fs=10_000)
zero_pole_plot("Chebyshev type I, digital", z, p)

# %%
data = []
data.append(signal.cheby2(4, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby2(4, 40, 200, btype="highpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby2(4, 40, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000))
data.append(signal.cheby2(4, 40, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000))

z = [i[0] for i in data]
p = [i[1] for i in data]
q = signal.butter(4, 100, btype="lowpass", analog=False, output="zpk", fs=10_000)
zero_pole_plot("Chebyshev type II, digital", z, p)

# %%
data = []
data.append(signal.ellip(4, 5, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
data.append(signal.ellip(4, 5, 40, 200, btype="highpass", analog=False, output="ba", fs=10_000))
data.append(signal.ellip(4, 5, 40, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000))
data.append(signal.ellip(4, 5, 40, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000))

z = [i[0] for i in data]
p = [i[1] for i in data]
q = signal.butter(4, 100, btype="lowpass", analog=False, output="zpk", fs=10_000)
zero_pole_plot("Elliptic, digital", z, p)

# %% [markdown]
# ## Задание 4
# Нарисовать диаграммы Боде для ФНЧ всех четырех вариантов, варьируя порядок фильтра.
#
# Я не могу сказать что с фильтрами Чебышева 2 рода и эллиптическим. Может они просто очень похожи для разных порядков и накладываются на рисунке. А может числовая нестабильность из-за использования ```ba``` вместо ```sos``` (см. варнинг ниже).

# %%
def make_plot(w: list, mag: list, phase: list) -> None:
    subtitle = ["Butterworth", "Chebyshev type I", "Chebyshev type II", "Elliptic"]
    fig = plt.figure(figsize=(10, 8), dpi=130)
    outer = gridspec.GridSpec(2, 2)

    for i in range(4):
        inner = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=outer[i])

        ax = plt.Subplot(fig, inner[0])
        ax.set_title(subtitle[i])
        for j in range(10):
            ax.semilogx(w[i][j], mag[i][j])
        ax.grid(which='both', axis='both')
        fig.add_subplot(ax)

        ax = plt.Subplot(fig, inner[1])
        for j in range(10):
            ax.semilogx(w[i][j], phase[i][j])
        ax.grid(which='both', axis='both')
        fig.add_subplot(ax)
    fig.tight_layout()

# %%
w, mag, phase = [], [], []
w__ , mag__, phase__ = [], [], []
for i in range(10):
    w_, mag_, phase_ = signal.dbode(signal.TransferFunction(*signal.butter(i, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05))
    w__.append(w_)
    mag__.append(mag_)
    phase__.append(phase_)
w.append(w__)
mag.append(mag__)
phase.append(phase__)

w__ , mag__, phase__ = [], [], []
for i in range(10):
    w_, mag_, phase_ = signal.dbode(signal.TransferFunction(*signal.cheby1(i, 5, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05))
    w__.append(w_)
    mag__.append(mag_)
    phase__.append(phase_)
w.append(w__)
mag.append(mag__)
phase.append(phase__)

w__ , mag__, phase__ = [], [], []
for i in range(10):
    data.append(signal.dbode(signal.TransferFunction(*signal.cheby2(i, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
    w__.append(w_)
    mag__.append(mag_)
    phase__.append(phase_)
w.append(w__)
mag.append(mag__)
phase.append(phase__)

w__ , mag__, phase__ = [], [], []
for i in range(10):
    data.append(signal.dbode(signal.TransferFunction(*signal.ellip(i, 5, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000), dt=0.05)))
    w__.append(w_)
    mag__.append(mag_)
    phase__.append(phase_)
w.append(w__)
mag.append(mag__)
phase.append(phase__)


# print(len(w[0]))
make_plot(w, mag, phase)
# Out:
# c:\Users\Wicirelllis\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\signal\_filter_design.py:1709: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "

# %% [markdown]
# ## Задание 5
# Применить фильтры, рассмотренные выше, к сигналу - последовательности прямоугольных импульсов.

# %%
t = np.linspace(0, 1./100, 300)
sig = signal.square(2 * np.pi * 300 * t)
fig, ax = plt.subplots(2, dpi=150)
fig.autofmt_xdate(rotation=45)
ax[0].plot(t, sig)
ax[0].set_title("Square wave")

x_ = fft.fftfreq(len(sig), 1/300)
y_ = np.abs(fft.fft(sig)) / len(t)
x, y = zip(*sorted(zip(x_, y_)))
ax[1].plot(x, y)
ax[1].set_title("Spectrum")
# Out:
# Text(0.5, 1.0, 'Spectrum')

# %%
ba = []
ba.append(signal.butter(4, 1000, btype="lowpass", analog=False, output="ba", fs=10_000))
ba.append(signal.butter(4, 2000, btype="highpass", analog=False, output="ba", fs=10_000))
ba.append(signal.butter(4, [100, 1000], btype="bandpass", analog=False, output="ba", fs=10_000))
ba.append(signal.butter(4, [100, 1000], btype="bandstop", analog=False, output="ba", fs=10_000))

subtitle = ["lowpass", "highpass", "bandpass", "bandstop"]
fig = plt.figure(figsize=(10, 8), dpi=130)
outer = gridspec.GridSpec(2, 2)

for i in range(4):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=outer[i])

    b, a = ba[i]
    filtered = signal.filtfilt(b, a, sig)

    ax = plt.Subplot(fig, inner[0])
    fig.autofmt_xdate(rotation=45)
    ax.set_title(subtitle[i])
    ax.plot(t, filtered)
    ax.plot(t, sig, alpha=0.5)
    fig.add_subplot(ax)

    ax = plt.Subplot(fig, inner[1])
    fig.autofmt_xdate(rotation=45)
    x_ = fft.fftfreq(len(filtered), 1/300)
    y_ = np.abs(fft.fft(filtered)) / len(t)
    x, y = zip(*sorted(zip(x_, y_)))
    ax.plot(x, y)
    fig.add_subplot(ax)
fig.tight_layout()

# %%
ba = []
ba.append(signal.butter(4, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
ba.append(signal.cheby1(4, 5, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
ba.append(signal.cheby2(4, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000))
ba.append(signal.ellip(4, 5, 40, 100, btype="lowpass", analog=False, output="ba", fs=10_000))

subtitle = ["Butterworth", "Chebyshev type I", "Chebyshev type II", "Elliptic"]
fig = plt.figure(figsize=(10, 8), dpi=130)
outer = gridspec.GridSpec(2, 2)

for i in range(4):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=outer[i])

    b, a = ba[i]
    filtered = signal.filtfilt(b, a, sig)

    ax = plt.Subplot(fig, inner[0])
    fig.autofmt_xdate(rotation=45)
    ax.set_title(subtitle[i])
    ax.plot(t, filtered)
    ax.plot(t, sig, alpha=0.5)
    fig.add_subplot(ax)

    ax = plt.Subplot(fig, inner[1])
    fig.autofmt_xdate(rotation=45)
    x_ = fft.fftfreq(len(filtered), 1/300)
    y_ = np.abs(fft.fft(filtered)) / len(t)
    x, y = zip(*sorted(zip(x_, y_)))
    ax.plot(x, y)
    fig.add_subplot(ax)
fig.tight_layout()
